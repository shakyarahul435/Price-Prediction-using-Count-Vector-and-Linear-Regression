# %%
import pandas as pd

# %%
df = pd.read_csv("file.csv")
df
# Out:
#     Date  Bill No.     Pan No.                             particulars  \
# 0   16.0       1.0         NaN                                Tilahari
# 1   19.0       2.0      solved                                    Mala
# 2   19.0       3.0      solved                                 marwadi
# 3   20.0       4.0         NaN                        Sikri and Locket
# 4   25.0       5.0         NaN                                   Authi
# 5    2.0       6.0     damaged                                     NaN
# 6   25.0       7.0         NaN                                 Braclet
# 7   25.0       8.0         NaN                                   Authi
# 8   25.0       9.0         NaN                                   Sikri
# 9   25.0      10.0         NaN                                   Sikri
# 10  25.0      11.0         NaN                                   Sikri
# 11   5.0      12.0     damaged                                     NaN
# ...

# %%
features = df[['particulars','Grand Total']]
features
# Out:
#                                particulars  Grand Total
# 0                                 Tilahari      10434.0
# 1                                     Mala      48240.0
# 2                                  marwadi      22684.0
# 3                         Sikri and Locket      83073.0
# 4                                    Authi      15209.0
# 5                                      NaN          0.0
# 6                                  Braclet       9852.0
# 7                                    Authi      15888.0
# 8                                    Sikri       4464.0
# 9                                    Sikri     154897.0
# 10                                   Sikri       1500.0
# 11                                     NaN          0.0
# 12                                  Locket      14110.0
# 13                                     Top       1900.0
# 14                                  Locket      77744.0
# 15                                   Sikri     108200.0
# ...

# %%
features= features.dropna()

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
X = features.drop("particulars",axis=1)
y = features[["particulars"]]
X_train,X_test,y_train,y_test = train_test_split(features["particulars"],y,test_size=0.2)
model = DecisionTreeRegressor()

# %%
X_train
# Out:
# 0             Tilahari
# 2              marwadi
# 40               Sikri
# 1                 Mala
# 51             Tilhari
# 44          Bala Chura
# 46    Nau Ratna Locket
# 8                Sikri
# 9                Sikri
# 13                 Top
# 4                Authi
# 3     Sikri and Locket
# 43            Necklace
# 52               Authi
# 15               Sikri
# 41              Jhumka
# 14              Locket
# 42         Kanye Sikri
# 17             Tilhari
# 54         Mangalsutra
# 39           Tilhari*3
# 45               Sikri
# 49            Necklace
# 12              Locket
# 7                Authi
# 16             Tilhari
# Name: particulars, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
import numpy as np

df = pd.DataFrame(features)

X_train, X_test, y_train, y_test = train_test_split(df['particulars'], df['Grand Total'], test_size=0.2, random_state=42)

model = make_pipeline(CountVectorizer(), LinearRegression())

model.fit(X_train, y_train)


predictions = model.predict(X_test)

names = input("Enter the name of the jewellery:")
name = [names]
predicted_price = model.predict(name)
print(f'Predicted Price for {names}: Rs.{predicted_price[0]}')
# Out:
# Enter the name of the jewellery:tilahari
# Predicted Price for tilahari: Rs.10433.999999999854

# %%
df = pd.DataFrame(features)
df
# Out:
#          particulars  Grand Total
# 0           Tilahari      10434.0
# 1               Mala      48240.0
# 2            marwadi      22684.0
# 3   Sikri and Locket      83073.0
# 4              Authi      15209.0
# 6            Braclet       9852.0
# 7              Authi      15888.0
# 8              Sikri       4464.0
# 9              Sikri     154897.0
# 10             Sikri       1500.0
# 12            Locket      14110.0
# 13               Top       1900.0
# 14            Locket      77744.0
# 15             Sikri     108200.0
# 16           Tilhari      35238.0
# 17           Tilhari      40170.0
# 39         Tilhari*3      72449.0
# 40             Sikri      52557.0
# 41            Jhumka      54204.0
# 42       Kanye Sikri      55356.0
# 43          Necklace      85944.0
# 44        Bala Chura     112403.0
# 45             Sikri      20925.0
# 46  Nau Ratna Locket       9213.0
# 47            Jhumka      60636.0
# 48           Tilhari      30079.0
# ...
